# %%
from ctapipe.utils.datasets import get_path
from ctapipe.io.hessio import hessio_event_source
from ctapipe import visualization, io
from matplotlib import pyplot as plt
from astropy import units as u
from ctapipe.visualization import CameraDisplay
from ctapipe.io import CameraGeometry
import numpy as np
# %matplotlib inline

# %%
source = hessio_event_source(get_path("/Users/Jason/Software/outputs/sim_telarray/simtel_run4_gcts_hnsb.gz"), max_events=100)

# %%
event = next(source)
event = next(source)
event.dl0.event_id
# Out:
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# 205

# %%
tels = list(event.dl0.tels_with_data)
tels
# Out:
# [16, 10]

# %%
teldata = event.dl0.tel[tels[0]]
print(teldata)
# Out:
# {'_name': 'CT016',
#  'adc_samples': {0: array([[41, 43, 38, ..., 34, 40, 40],
#        [39, 43, 48, ..., 27, 28, 28],
#        [30, 24, 27, ..., 38, 34, 32],
#        ...,
#        [43, 44, 46, ..., 30, 27, 26],
#        [36, 44, 43, ..., 31, 31, 29],
#        [58, 59, 61, ..., 49, 40, 42]], dtype=uint16)},
#  'adc_sums': {0: array([3173, 3121, 2810, ..., 3135, 2876, 3759], dtype=int32)},
#  'num_channels': 1}

# %%
img = teldata.adc_samples[0]

# %%
img.shape
# Out:
# (2048, 80)

# %%
plt.pcolormesh(img)  # note the [0] is for channel 0
plt.xlabel("sample number")
plt.ylabel("Pixel_id")
maxpix = np.unravel_index(np.argmax(img),img.shape)

# %%
geom = CameraGeometry.guess(*event.meta.pixel_pos[15])

# %%
geom.cam_id
# Out:
# 'GATE'

# %%
plt.rcParams['figure.figsize'] = (20.0, 16.0)

disp = CameraDisplay(geom)
disp.image = img[:,maxpix[1]]
disp.cmap = plt.cm.RdBu_r
disp.add_colorbar()
disp.set_limits_percent(95)  # autoscale

# %%
trace = teldata.adc_samples[0][maxpix[0]]   
plt.plot(trace)

# %%
from scipy import signal
import numpy as np

# %%
pix_ids = np.arange(len(data))
has_signal = sums > 300

widths = np.array([8,]) # peak widths to search for (let's fix it at 8 samples, about the width of the peak)
peaks = [signal.find_peaks_cwt(trace,widths) for trace in data[has_signal] ]

for p,s in zip(pix_ids[has_signal],peaks):
    print("pix{} has peaks at sample {}".format(p,s))
    plt.plot(data[p])
    plt.scatter(np.array(s),data[p,s])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-311-dd08518d9350> in <module>()
# ----> 1 pix_ids = np.arange(len(data))
#       2 has_signal = sums > 300
#       3
#       4 widths = np.array([8,]) # peak widths to search for (let's fix it at 8 samples, about the width of the peak)
#       5 peaks = [signal.find_peaks_cwt(trace,widths) for trace in data[has_signal] ]
#
# NameError: name 'data' is not defined
